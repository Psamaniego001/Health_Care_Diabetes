# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
#################################################
# Database Setup
#################################################
# Create an engine to connect to the PostgreSQL database
engine_postgres = create_engine("postgresql://postgres:POSTGRES@localhost:5432/Listings_db")

# %%
# Query data from PostgreSQL and load into Pandas DataFrames
listings_df = pd.read_sql("SELECT * FROM listings", engine_postgres)

# Now you have your data in Pandas DataFrames and can work with it as needed
listings_df.head()
# Out:
#    unique_identifier  listing_amount  amount_funded  lender_yield  \
# 0                  0           17300          17300        0.1349
# 1                  1           25000          25000        0.0999
# 2                  2            3500           3500        0.1179
# 3                  3            5000           5000        0.0964
# 4                  4           21795          21795        0.0530
#
#    borrower_apr  listing_term  listing_monthly_payment  income_range  \
# 0        0.1683            60                   406.95             6
# 1        0.1325            60                   543.44             6
# 2        0.1641            36                   117.58             4
# 3        0.1422            36                   162.84             4
# 4        0.0795            36                   666.01             6
#
#   income_range_description  stated_monthly_income  ...  lender_indicator  \
# 0                $100,000+             11250.0000  ...                 0
# 1                $100,000+             15416.6667  ...                 0
# 2           $50,000-74,999              4166.6667  ...                 0
# 3           $50,000-74,999              5000.0000  ...                 0
# 4                $100,000+             20000.0000  ...                 0
#
#   group_indicator fico_rating  tuficorange  dti_wprosper_loan  \
# 0           False           6      760-779             0.2377
# 1           False           6      760-779             0.2900
# 2           False           3      700-719             0.0309
# 3           False           1      660-679             0.1818
# 4           False           9      820-850             0.1816
#
#   coborrowerapplication combineddtiwprosperloan  combinedstatedmonthlyincome  \
# 0                  True                  0.2377                   16250.0000
# 1                  True                  0.2900                   22333.3333
# 2                  True                  0.0309                    7500.0000
# 3                  True                  0.1818                    8333.3333
# 4                  True                  0.1816                   23833.3333
#
#    rating_num  prosper_rating
# 0           1               B
# 1           0               A
# 2           1               B
# 3           0               A
# 4           0              AA
#
# [5 rows x 35 columns]
